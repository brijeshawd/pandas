# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![Screenshot 2022-07-07 at 20.45.25.png](data:image/png;base64,...)

# %% [markdown]
# Dataset links
#
# weather - https://drive.google.com/file/d/1wG8GaMi1hhfY6DsUPFjFtDYkumA-m2Xj/view
#
# weather1 - https://drive.google.com/file/d/1tCYv0EBjwPX2aHbZpwJRhYzVDd5rTl9o/view?usp=sharing
#
# weather2 - https://drive.google.com/file/d/1V1RkggkaKmWw0Yv9ywlRdcBUDkZnQMeh/view?usp=sharing
#
# weather3 - https://drive.google.com/file/d/1_dPnZS-91ANpimUWy4cMjNqv5yeKxFJ4/view?usp=sharing
#
# weather4 - https://drive.google.com/file/d/1YOSfGrKPoKSyZuKbjFgtz_8FVisbvZlP/view?usp=sharing
#
# uber - https://drive.google.com/file/d/1TL2hWkMWtD1ExVgaQhWP6A2swR8F8cVB/view?usp=sharing

# %%
# !gdown 1wG8GaMi1hhfY6DsUPFjFtDYkumA-m2Xj
# !gdown 1tCYv0EBjwPX2aHbZpwJRhYzVDd5rTl9o
# !gdown 1V1RkggkaKmWw0Yv9ywlRdcBUDkZnQMeh
# !gdown 1_dPnZS-91ANpimUWy4cMjNqv5yeKxFJ4
# !gdown 1YOSfGrKPoKSyZuKbjFgtz_8FVisbvZlP
# !gdown 1TL2hWkMWtD1ExVgaQhWP6A2swR8F8cVB
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wG8GaMi1hhfY6DsUPFjFtDYkumA-m2Xj
# To: /content/weather.csv
# 100% 12.0k/12.0k [00:00<00:00, 15.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1tCYv0EBjwPX2aHbZpwJRhYzVDd5rTl9o
# To: /content/weather1.csv
# 100% 241/241 [00:00<00:00, 288kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1V1RkggkaKmWw0Yv9ywlRdcBUDkZnQMeh
# To: /content/weather2.csv
# 100% 215/215 [00:00<00:00, 262kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_dPnZS-91ANpimUWy4cMjNqv5yeKxFJ4
# To: /content/weather3.csv
# 100% 178/178 [00:00<00:00, 223kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YOSfGrKPoKSyZuKbjFgtz_8FVisbvZlP
# To: /content/weather4.csv
# 100% 150/150 [00:00<00:00, 163kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TL2hWkMWtD1ExVgaQhWP6A2swR8F8cVB
# To: /content/UberDrives.csv
# 100% 86.4k/86.4k [00:00<00:00, 48.9MB/s]

# %%
weather=pd.read_csv("weather.csv")
weather1=pd.read_csv("weather1.csv")
weather2=pd.read_csv("weather2.csv")
weather3=pd.read_csv("weather3.csv")
weather4=pd.read_csv("weather4.csv")

# %%
weather.head(22)
# weather.shape
# Out:
#     year  month element       day1       day2       day3       day4  \
# 0   2018      1     max  17.573016  19.796815  22.412495  17.813163
# 1   2018      1     min  22.725760  21.007865  17.730792  18.045290
# 2   2018      2     max  19.015120  19.261805  17.510713  21.080425
# 3   2018      2     min  18.653843  22.818600  21.842673  21.958159
# 4   2018      3     max  20.741115  19.704016  17.039811  20.703908
# 5   2018      3     min  17.250431  20.325829  21.473071  18.132962
# 6   2018      4     max  20.408029  21.634346  22.677863  20.839558
# 7   2018      4     min  21.849449  19.659674  18.009526  19.450892
# 8   2018      5     max  21.354089  21.806705  19.863229  22.475220
# 9   2018      5     min  18.889095  20.123320  19.376866  21.989649
# 10  2018      6     max  22.419377  20.389671  22.669923  22.810337
# 11  2018      6     min  21.121687  19.357005  17.346115  17.359855
# 12  2018      7     max  19.006195  19.512117  21.249908  19.472257
# ...

# %%
weather.shape
# Out:
# (22, 34)

# %%
# weather.T

# %%
weather_melt=weather.melt(id_vars=["year","month","element"],
                         var_name="day",
                         value_name="temperature")
weather_melt.head(50)
# Out:
#     year  month element   day  temperature
# 0   2018      1     max  day1    17.573016
# 1   2018      1     min  day1    22.725760
# 2   2018      2     max  day1    19.015120
# 3   2018      2     min  day1    18.653843
# 4   2018      3     max  day1    20.741115
# 5   2018      3     min  day1    17.250431
# 6   2018      4     max  day1    20.408029
# 7   2018      4     min  day1    21.849449
# 8   2018      5     max  day1    21.354089
# 9   2018      5     min  day1    18.889095
# 10  2018      6     max  day1    22.419377
# 11  2018      6     min  day1    21.121687
# 12  2018      7     max  day1    19.006195
# 13  2018      7     min  day1    19.704782
# 14  2018      8     max  day1    21.736412
# 15  2018      8     min  day1    18.896222
# 16  2018     10     max  day1    18.503314
# 17  2018     10     min  day1    22.845420
# 18  2018     11     max  day1    17.994997
# 19  2018     11     min  day1    22.275672
# 20  2018     12     max  day1    17.367511
# ...

# %%
weather_melt.shape
# Out:
# (682, 5)

# %%
weather
# Out:
#     year  month element       day1       day2       day3       day4  \
# 0   2018      1     max  17.573016  19.796815  22.412495  17.813163
# 1   2018      1     min  22.725760  21.007865  17.730792  18.045290
# 2   2018      2     max  19.015120  19.261805  17.510713  21.080425
# 3   2018      2     min  18.653843  22.818600  21.842673  21.958159
# 4   2018      3     max  20.741115  19.704016  17.039811  20.703908
# 5   2018      3     min  17.250431  20.325829  21.473071  18.132962
# 6   2018      4     max  20.408029  21.634346  22.677863  20.839558
# 7   2018      4     min  21.849449  19.659674  18.009526  19.450892
# 8   2018      5     max  21.354089  21.806705  19.863229  22.475220
# 9   2018      5     min  18.889095  20.123320  19.376866  21.989649
# 10  2018      6     max  22.419377  20.389671  22.669923  22.810337
# 11  2018      6     min  21.121687  19.357005  17.346115  17.359855
# 12  2018      7     max  19.006195  19.512117  21.249908  19.472257
# ...

# %%
weather4
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
weather_melted=weather4.melt(id_vars="day",
             var_name="city",
             value_name="temp")
weather_melted
# Out:
#           day     city  temp
# 0      Monday  chicago    32
# 1     Tuesday  chicago    30
# 2   Wednesday  chicago    28
# 3    Thursday  chicago    22
# 4      Friday  chicago    30
# 5    Saturday  chicago    20
# 6      Sunday  chicago    25
# 7      Monday  chennai    75
# 8     Tuesday  chennai    77
# 9   Wednesday  chennai    75
# 10   Thursday  chennai    82
# 11     Friday  chennai    83
# 12   Saturday  chennai    81
# 13     Sunday  chennai    77
# 14     Monday   berlin    41
# 15    Tuesday   berlin    43
# 16  Wednesday   berlin    45
# 17   Thursday   berlin    38
# 18     Friday   berlin    30
# 19   Saturday   berlin    45
# 20     Sunday   berlin    47

# %%
weather4.melt()
# Out:
#    variable      value
# 0       day     Monday
# 1       day    Tuesday
# 2       day  Wednesday
# 3       day   Thursday
# 4       day     Friday
# 5       day   Saturday
# 6       day     Sunday
# 7   chicago         32
# 8   chicago         30
# 9   chicago         28
# 10  chicago         22
# 11  chicago         30
# 12  chicago         20
# 13  chicago         25
# 14  chennai         75
# 15  chennai         77
# 16  chennai         75
# 17  chennai         82
# 18  chennai         83
# 19  chennai         81
# 20  chennai         77
# 21   berlin         41
# 22   berlin         43
# 23   berlin         45
# 24   berlin         38
# 25   berlin         30
# 26   berlin         45
# 27   berlin         47

# %%
weather_melt.head(4)
# Out:
#    year  month element   day  temperature
# 0  2018      1     max  day1    17.573016
# 1  2018      1     min  day1    22.725760
# 2  2018      2     max  day1    19.015120
# 3  2018      2     min  day1    18.653843

# %%
weather_tidy=weather_melt.pivot(index=["year","month","day"],
                               columns="element",
                               values="temperature")
weather_tidy
# Out:
# element                 max        min
# year month day
# 2018 1     day1   17.573016  22.725760
#            day10  19.067288  19.931129
#            day11  19.361002  22.598325
#            day12  20.982134  17.715137
#            day13  21.668005  17.940334
# ...                     ...        ...
#      12    day5   21.375349  20.865535
#            day6   17.992885  20.310116
#            day7   19.683359  20.531823
#            day8   20.477046  19.310346
#            day9   20.210640  22.820992
#
# [341 rows x 2 columns]

# %%
weather_tidy.head(20)
# Out:
# element                 max        min
# year month day
# 2018 1     day1   17.573016  22.725760
#            day10  19.067288  19.931129
#            day11  19.361002  22.598325
#            day12  20.982134  17.715137
#            day13  21.668005  17.940334
#            day14  19.441664  19.853651
#            day15  17.609544  18.662379
#            day16  20.245582  17.215839
#            day17  17.386774  21.662470
#            day18  22.549572  17.202508
#            day19  19.898544  19.697496
#            day2   19.796815  21.007865
#            day20  20.836153  22.182156
#            day21  18.427361  21.532442
#            day22  22.629226  21.163491
#            day23  19.013674  17.371653
#            day24  17.831558  17.194530
#            day25  17.018316  18.964190
#            day26  21.837387  17.892385
#            day27  19.700255  17.646139

# %%
weather_tidy=weather_tidy.reset_index()
weather_tidy
# Out:
# element  year  month    day        max        min
# 0        2018      1   day1  17.573016  22.725760
# 1        2018      1  day10  19.067288  19.931129
# 2        2018      1  day11  19.361002  22.598325
# 3        2018      1  day12  20.982134  17.715137
# 4        2018      1  day13  21.668005  17.940334
# ..        ...    ...    ...        ...        ...
# 336      2018     12   day5  21.375349  20.865535
# 337      2018     12   day6  17.992885  20.310116
# 338      2018     12   day7  19.683359  20.531823
# 339      2018     12   day8  20.477046  19.310346
# 340      2018     12   day9  20.210640  22.820992
#
# [341 rows x 5 columns]

# %%
weather1
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
weather1.pivot(index="city",
             columns="date")
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
weather1.pivot(index="city",
             columns="date",
              values="humidity")
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df1=weather1.pivot(index="date",
             columns="city")
df1
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
weather1.pivot(index="date",
             columns="city",
              values="temperature")
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       80      75        65
# 5/2/2017       77      78        66
# 5/3/2017       79      82        68

# %%
df1.columns
# Out:
# MultiIndex([('temperature',  'beijing'),
#             ('temperature',   'mumbai'),
#             ('temperature', 'new york'),
#             (   'humidity',  'beijing'),
#             (   'humidity',   'mumbai'),
#             (   'humidity', 'new york')],
#            names=[None, 'city'])

# %%
weather2
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
weather2.pivot_table(index="city",
                    columns="date",
                    aggfunc="mean",
                    margins=True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %%
weather2.pivot_table(index="city",
                    columns="date",
                    aggfunc="max",
                    margins=True)
# Out:
#          humidity              temperature
# date     5/1/2017 5/2/2017 All    5/1/2017 5/2/2017 All
# city
# mumbai         83       85  85          78       82  82
# new york       56       62  62          65       72  72
# All            83       85  85          78       82  82

# %%
weather2.pivot_table(index="city",
                    columns="date",
                    aggfunc="min",
                    margins=True)
# Out:
#          humidity              temperature
# date     5/1/2017 5/2/2017 All    5/1/2017 5/2/2017 All
# city
# mumbai         80       26  26          75       80  75
# new york       54       60  54          61       70  61
# All            54       26  26          61       70  61

# %%
weather2.pivot_table(index="city",
                    columns="date",
                    aggfunc="min")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai         80       26          75       80
# new york       54       60          61       70

# %%
weather2.pivot_table(index="city",
                    columns="date",
                    aggfunc=["mean","max"],
                    margins=True)
# Out:
#              mean                                                   max  \
#          humidity                 temperature                  humidity
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All 5/1/2017
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750       83
# new york    55.00    61.00  58.00       63.00     71.0  67.000       56
# All         68.25    58.25  63.25       69.75     76.0  72.875       83
#
#
#                       temperature
# date     5/2/2017 All    5/1/2017 5/2/2017 All
# city
# mumbai         85  85          78       82  82
# new york       62  62          65       72  72
# All            85  85          78       82  82

# %%
weather_tidy.head()
# Out:
# element  year  month    day        max        min
# 0        2018      1   day1  17.573016  22.725760
# 1        2018      1  day10  19.067288  19.931129
# 2        2018      1  day11  19.361002  22.598325
# 3        2018      1  day12  20.982134  17.715137
# 4        2018      1  day13  21.668005  17.940334

# %%
weather_tidy["max"].max()
# Out:
# 22.9403089333132

# %%
weather_tidy["max"].min()
# Out:
# 17.0021208843141

# %%
bins=[16,18,20,22,24]
labels=["low","medium","high","Very high"]
weather_tidy["max_category"]=pd.cut(weather_tidy["max"],
                                   bins=bins,
                                   labels=labels)
weather_tidy.head(20)
# Out:
# element  year  month    day        max        min max_category
# 0        2018      1   day1  17.573016  22.725760          low
# 1        2018      1  day10  19.067288  19.931129       medium
# 2        2018      1  day11  19.361002  22.598325       medium
# 3        2018      1  day12  20.982134  17.715137         high
# 4        2018      1  day13  21.668005  17.940334         high
# 5        2018      1  day14  19.441664  19.853651       medium
# 6        2018      1  day15  17.609544  18.662379          low
# 7        2018      1  day16  20.245582  17.215839         high
# 8        2018      1  day17  17.386774  21.662470          low
# 9        2018      1  day18  22.549572  17.202508    Very high
# 10       2018      1  day19  19.898544  19.697496       medium
# 11       2018      1   day2  19.796815  21.007865       medium
# 12       2018      1  day20  20.836153  22.182156         high
# 13       2018      1  day21  18.427361  21.532442       medium
# ...

# %%
bins=[16,20,22,24]
labels=["low","medium","high"]
weather_tidy["max_category"]=pd.cut(weather_tidy["max"],
                                   bins=bins,
                                   labels=labels)
weather_tidy
# Out:
# element  year  month    day        max        min max_category
# 0        2018      1   day1  17.573016  22.725760          low
# 1        2018      1  day10  19.067288  19.931129          low
# 2        2018      1  day11  19.361002  22.598325          low
# 3        2018      1  day12  20.982134  17.715137       medium
# 4        2018      1  day13  21.668005  17.940334       medium
# ..        ...    ...    ...        ...        ...          ...
# 336      2018     12   day5  21.375349  20.865535       medium
# 337      2018     12   day6  17.992885  20.310116          low
# 338      2018     12   day7  19.683359  20.531823          low
# 339      2018     12   day8  20.477046  19.310346       medium
# 340      2018     12   day9  20.210640  22.820992       medium
#
# [341 rows x 6 columns]

# %%
bins=[16,24,22,44]
labels=["low","medium","high"]
weather_tidy1=pd.cut(weather_tidy["max"],
                                   bins=bins,
                                   labels=labels)
weather_tidy1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hd/9z4dczb56dj54lb7q8w7s4zw0000gn/T/ipykernel_24038/962375619.py in <module>
#       1 bins=[16,24,22,44]
#       2 labels=["low","medium","high"]
# ----> 3 weather_tidy1=pd.cut(weather_tidy["max"],
#       4                                    bins=bins,
#       5                                    labels=labels)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     283         # GH 26045: cast to float64 to avoid an overflow
#     284         if (np.diff(bins.astype("float64")) < 0).any():
# --> 285             raise ValueError("bins must increase monotonically.")
#     286
#     287     fac, bins = _bins_to_cuts(
#
# ValueError: bins must increase monotonically.

# %%
weather_tidy.to_csv("Weather_tidy1.csv",sep=",")

# %%
# !ls
# Out:
# Pandas-1.ipynb    UberDrives.csv    gapminder.csv     weather2.csv
# Pandas-2.ipynb    Weather_tidy.csv  movies.csv        weather3.csv
# Pandas-3.ipynb    Weather_tidy1.csv weather.csv       weather4.csv
# Pandas-4.ipynb    directors.csv     weather1.csv

# %%
df2=pd.DataFrame([[np.nan, 2, np.nan, 0],
                   [3, 4, np.nan, 1],
                   [np.nan, np.nan, np.nan, np.nan],
                   [np.nan, 3, np.nan, 4]],
                  columns=["A","B","C","D"])
df2
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df2.isna().sum()
# Out:
# A    3
# B    1
# C    4
# D    1
# dtype: int64

# %%
df2.isna()
# Out:
#        A      B     C      D
# 0   True  False  True  False
# 1  False  False  True  False
# 2   True   True  True   True
# 3   True  False  True  False

# %%
df2.isnull()
# Out:
#        A      B     C      D
# 0   True  False  True  False
# 1  False  False  True  False
# 2   True   True  True   True
# 3   True  False  True  False

# %%
df2
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df2.isna().sum(axis=1)
# Out:
# 0    2
# 1    1
# 2    4
# 3    2
# dtype: int64

# %%
df2.isna().sum()
# Out:
# A    3
# B    1
# C    4
# D    1
# dtype: int64

# %%
df2
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df2.fillna(0)
# Out:
#      A    B    C    D
# 0  0.0  2.0  0.0  0.0
# 1  3.0  4.0  0.0  1.0
# 2  0.0  0.0  0.0  0.0
# 3  0.0  3.0  0.0  4.0

# %%
df2["A"].fillna(0)
# Out:
# 0    0.0
# 1    3.0
# 2    0.0
# 3    0.0
# Name: A, dtype: float64

# %%
df2["B"].fillna(df2["B"].mean())
# Out:
# 0    2.0
# 1    4.0
# 2    3.0
# 3    3.0
# Name: B, dtype: float64

# %%
df2["B"].fillna(df2["A"].mean())
# Out:
# 0    2.0
# 1    4.0
# 2    3.0
# 3    3.0
# Name: B, dtype: float64

# %%
df2["A"].mean()
# Out:
# 3.0

# %%
df2
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df2.fillna(method="ffill")
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  3.0  4.0 NaN  1.0
# 3  3.0  3.0 NaN  4.0

# %%
df2.fillna(method="bfill")
# Out:
#      A    B   C    D
# 0  3.0  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  3.0 NaN  4.0
# 3  NaN  3.0 NaN  4.0

# %%
uber=pd.read_csv("UberDrives.csv")

# %%
uber
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
uber.drop([1155],inplace=True)

# %%
uber
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
uber.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
uber[uber.duplicated()]
# Out:
#          START_DATE*        END_DATE* CATEGORY*  START* STOP*  MILES* PURPOSE*
# 492  6/28/2016 23:34  6/28/2016 23:59  Business  Durham  Cary     9.9  Meeting

# %%
uber.drop_duplicates(inplace=True)

# %%
uber[uber.duplicated()]
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
uber.columns=[s[:-1] for s in uber.columns]
uber
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
uber.describe(include="all")
# Out:
#             START_DATE        END_DATE  CATEGORY START  STOP        MILES  \
# count             1154            1154      1154  1154  1154  1154.000000
# unique            1154            1154         2   177   188          NaN
# top     1/1/2016 21:11  1/1/2016 21:17  Business  Cary  Cary          NaN
# freq                 1               1      1077   201   202          NaN
# mean               NaN             NaN       NaN   NaN   NaN    10.567418
# std                NaN             NaN       NaN   NaN   NaN    21.588452
# min                NaN             NaN       NaN   NaN   NaN     0.500000
# 25%                NaN             NaN       NaN   NaN   NaN     2.900000
# 50%                NaN             NaN       NaN   NaN   NaN     6.000000
# 75%                NaN             NaN       NaN   NaN   NaN    10.400000
# max                NaN             NaN       NaN   NaN   NaN   310.300000
#
#         PURPOSE
# count       652
# unique       10
# top     Meeting
# ...

# %%
uber["START_DATE"]=pd.to_datetime(uber["START_DATE"])
uber
# Out:
#               START_DATE          END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00    1/1/2016 21:17  Business       Fort Pierce
# 1    2016-01-02 01:25:00     1/2/2016 1:37  Business       Fort Pierce
# 2    2016-01-02 20:25:00    1/2/2016 20:38  Business       Fort Pierce
# 3    2016-01-05 17:31:00    1/5/2016 17:45  Business       Fort Pierce
# 4    2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# ...                  ...               ...       ...               ...
# 1150 2016-12-31 01:07:00   12/31/2016 1:14  Business           Kar?chi
# 1151 2016-12-31 13:24:00  12/31/2016 13:42  Business           Kar?chi
# 1152 2016-12-31 15:03:00  12/31/2016 15:38  Business  Unknown Location
# 1153 2016-12-31 21:32:00  12/31/2016 21:50  Business        Katunayake
# 1154 2016-12-31 22:08:00  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1154 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1154 non-null   datetime64[ns]
#  1   END_DATE    1154 non-null   object
#  2   CATEGORY    1154 non-null   object
#  3   START       1154 non-null   object
#  4   STOP        1154 non-null   object
#  5   MILES       1154 non-null   float64
#  6   PURPOSE     652 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 72.1+ KB

# %%
uber["END_DATE"]=pd.to_datetime(uber["END_DATE"])
uber
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# ...

# %%
uber[uber["END_DATE"]==uber["START_DATE"]]
# Out:
#              START_DATE            END_DATE  CATEGORY             START  \
# 751 2016-09-06 17:49:00 2016-09-06 17:49:00  Business  Unknown Location
# 761 2016-09-16 07:08:00 2016-09-16 07:08:00  Business  Unknown Location
# 798 2016-10-08 15:03:00 2016-10-08 15:03:00  Business           Karachi
# 807 2016-10-13 13:02:00 2016-10-13 13:02:00  Business         Islamabad
#
#                  STOP  MILES PURPOSE
# 751  Unknown Location   69.1     NaN
# 761  Unknown Location    1.6     NaN
# 798           Karachi    3.6     NaN
# 807         Islamabad    0.7     NaN

# %%
uber.drop([751,761,798,807],inplace=True)

# %%
uber[uber["END_DATE"]==uber["START_DATE"]]
# Out:
# Empty DataFrame
# Columns: [START_DATE, END_DATE, CATEGORY, START, STOP, MILES, PURPOSE]
# Index: []

# %%
ts=uber["END_DATE"][0]

# %%
ts
# Out:
# Timestamp('2016-01-01 21:17:00')

# %%
ts.year
# Out:
# 2016

# %%
ts.month
# Out:
# 1

# %%
ts.day
# Out:
# 1

# %%
ts.month_name()
# Out:
# 'January'

# %%
ts.day_name()
# Out:
# 'Friday'

# %%
ts.dayofweek
# Out:
# 4

# %%
ts.hour
# Out:
# 21

# %%
ts.minute
# Out:
# 17

# %%
ts.second
# Out:
# 0

# %%
uber["END_DATE"].dt.year
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 1150    2016
# 1151    2016
# 1152    2016
# 1153    2016
# 1154    2016
# Name: END_DATE, Length: 1150, dtype: int64

# %%
uber["year"]=uber["END_DATE"].dt.year
uber
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE  year
# ...

# %%
uber.describe()
# Out:
#              MILES    year
# count  1150.000000  1150.0
# mean     10.538957  2016.0
# std      21.552360     0.0
# min       0.500000  2016.0
# 25%       2.900000  2016.0
# 50%       6.000000  2016.0
# 75%      10.400000  2016.0
# max     310.300000  2016.0

# %%
uber["MILES"].mean()
# Out:
# 10.538956521739115

# %%
uber["MILES"].median()
# Out:
# 6.0

# %%
uber["MILES"].max()
# Out:
# 310.3

# %%
uber["MILES"].std()
# Out:
# 21.552359680264498

# %%
np.percentile(uber["MILES"],25)
# Out:
# 2.9

# %%
np.percentile(uber["MILES"],75)
# Out:
# 10.4

# %%
np.percentile(uber["MILES"],75)-np.percentile(uber["MILES"],25)
# Out:
# 7.5

# %%
from scipy import stats

# %%
stats.iqr(uber["MILES"])
# Out:
# 7.5

# %%
2.9-(1.5*7.5)
# Out:
# -8.35

# %%
10.4+(1.5*7.5)
# Out:
# 21.65

# %%
uber[uber["MILES"]>21.65]
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# 25   2016-01-14 16:29:00 2016-01-14 17:05:00  Business           Houston
# 36   2016-01-20 13:25:00 2016-01-20 14:19:00  Business           Raleigh
# 62   2016-02-01 12:10:00 2016-02-01 12:43:00  Business       Chapel Hill
# 108  2016-02-16 03:21:00 2016-02-16 04:13:00  Business        Katunayaka
# ...                  ...                 ...       ...               ...
# 979  2016-11-20 10:27:00 2016-11-20 11:32:00  Business              Cary
# 1088 2016-12-21 20:56:00 2016-12-21 23:42:00  Business        Rawalpindi
# 1089 2016-12-22 15:40:00 2016-12-22 16:38:00  Business  Unknown Location
# 1092 2016-12-22 17:56:00 2016-12-22 18:29:00  Business  Unknown Location
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE  year
# ...
